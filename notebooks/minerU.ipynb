# %%
# !pip install --upgrade pip
# !pip install uv
# !uv pip install -U "mineru[core]"
# Out:
# Requirement already satisfied: pip in /usr/local/lib/python3.12/dist-packages (24.1.2)
# Collecting pip
#   Downloading pip-25.2-py3-none-any.whl.metadata (4.7 kB)
# Downloading pip-25.2-py3-none-any.whl (1.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.8/1.8 MB 49.2 MB/s eta 0:00:00
# Installing collected packages: pip
#   Attempting uninstall: pip
#     Found existing installation: pip 24.1.2
#     Uninstalling pip-24.1.2:
#       Successfully uninstalled pip-24.1.2
# Successfully installed pip-25.2
# Collecting uv
#   Downloading uv-0.9.2-py3-none-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (11 kB)
# Downloading uv-0.9.2-py3-none-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (21.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.2/21.2 MB 142.1 MB/s  0:00:00
# Installing collected packages: uv
# Successfully installed uv-0.9.2
# Using Python 3.12.12 environment at: /usr
# Resolved 149 packages in 1.44s
# Prepared 31 packages in 4.64s
# Uninstalled 23 packages in 432ms
# Installed 31 packages in 206ms
#  - beautifulsoup4==4.13.5
#  + beautifulsoup4==4.14.2
#  - charset-normalizer==3.4.3
#  + charset-normalizer==3.4.4
#  - cryptography==43.0.3
#  + cryptography==46.0.2
#  - dill==0.3.8
#  + dill==0.4.0
#  + doclayout-yolo==0.0.4
#  - fastapi==0.118.2
#  + fastapi==0.119.0
#  - ffmpy==0.6.2
#  + ffmpy==0.6.3
#  - fsspec==2025.3.0
#  + fsspec==2025.9.0
#  + ftfy==6.3.1
#  - gradio==5.49.0
#  + gradio==5.49.1
#  + gradio-pdf==0.0.22
#  - idna==3.10
#  + idna==3.11
#  - matplotlib==3.10.0
#  + matplotlib==3.10.7
#  - numpy==2.0.2
#  + numpy==2.3.3
#  - opencv-python==4.12.0.88
#  + opencv-python==4.11.0.86
#  - opencv-python-headless==4.12.0.88
#  + opencv-python-headless==4.11.0.86
#  - pandas==2.2.2
#  + pandas==2.3.3
#  - polars==1.25.2
#  + polars==1.34.0
#  + polars-runtime-32==1.34.0
#  - protobuf==5.29.5
#  + protobuf==6.32.1
#  - psutil==5.9.5
#  + psutil==7.1.0
#  + pyclipper==1.3.0.post6
#  - regex==2024.11.6
#  + regex==2025.9.18
#  - requests==2.32.4
#  + requests==2.32.5
#  - rich==13.9.4
#  + rich==14.2.0
#  - setuptools==75.2.0
#  + setuptools==80.9.0
#  - stringzilla==4.2.0
#  + stringzilla==4.2.1
#  - sympy==1.13.3
#  + sympy==1.14.0
#  + thop==0.1.1.post2209072238
#  + ultralytics==8.3.214
#  + ultralytics-thop==2.0.17

# %%
# !mineru -p /content/TBS_Handbook-2022.pdf \
        -o /content/sample_data \
        -m txt \
        -t true \
        -f true \
        --vram 14
# Out:
# Creating new Ultralytics Settings v0.0.6 file ✅
# View Ultralytics Settings with 'yolo settings' or at '/root/.config/Ultralytics/settings.json'
# Update Settings with 'yolo settings key=value', i.e. 'yolo settings runs_dir=path/to/dir'. For help see https://docs.ultralytics.com/quickstart/#ultralytics-settings.
# 2025-10-14 14:52:50.981 | INFO     | mineru.backend.pipeline.pipeline_analyze:doc_analyze:125 - Batch 1/1: 30 pages/30 pages
# 2025-10-14 14:52:51.004 | INFO     | mineru.backend.pipeline.pipeline_analyze:batch_image_analyze:187 - gpu_memory: 14 GB, batch_ratio: 8
# 2025-10-14 14:52:51.004 | INFO     | mineru.backend.pipeline.model_init:__init__:192 - DocAnalysis init, this may take some times......
# Fetching 1 files:   0% 0/1 [00:00<?, ?it/s]
# models/MFD/YOLO/yolo_v8_ft.pt:   0% 0.00/350M [00:00<?, ?B/s]
# models/MFD/YOLO/yolo_v8_ft.pt:   4% 14.5M/350M [00:01<00:41, 8.07MB/s]
# models/MFD/YOLO/yolo_v8_ft.pt:  23% 81.6M/350M [00:02<00:05, 48.6MB/s]
# models/MFD/YOLO/yolo_v8_ft.pt:  43% 149M/350M [00:02<00:02, 71.7MB/s]
# models/MFD/YOLO/yolo_v8_ft.pt:  62% 216M/350M [00:08<00:06, 22.1MB/s]
# models/MFD/YOLO/yolo_v8_ft.pt:  81% 283M/350M [00:08<00:01, 35.0MB/s]
# models/MFD/YOLO/yolo_v8_ft.pt: 100% 350M/350M [00:12<00:00, 28.1MB/s]
# Fetching 1 files: 100% 1/1 [00:13<00:00, 13.06s/it]
# Fetching 7 files:   0% 0/7 [00:00<?, ?it/s]
# special_tokens_map.json: 100% 552/552 [00:00<00:00, 5.65MB/s]
#
# README.md: 1.66kB [00:00, 3.38MB/s]
# Fetching 7 files:  14% 1/7 [00:00<00:03,  1.86it/s]
# tokenizer_config.json: 4.52kB [00:00, 3.73MB/s]
#
# config.json: 5.09kB [00:00, 24.6MB/s]
#
# tokenizer.json: 0.00B [00:00, ?B/s]
#
# generation_config.json: 100% 191/191 [00:00<00:00, 1.80MB/s]
# tokenizer.json: 3.58MB [00:00, 254MB/s]
#
# models/MFR/unimernet_hf_small_2503/model(…):   0% 0.00/810M [00:00<?, ?B/s]
# models/MFR/unimernet_hf_small_2503/model(…):   1% 5.14M/810M [00:01<02:58, 4.50MB/s]
# models/MFR/unimernet_hf_small_2503/model(…):   9% 72.2M/810M [00:02<00:19, 38.4MB/s]
# models/MFR/unimernet_hf_small_2503/model(…):  17% 139M/810M [00:02<00:10, 64.7MB/s]
# models/MFR/unimernet_hf_small_2503/model(…):  25% 206M/810M [00:04<00:11, 52.8MB/s]
# models/MFR/unimernet_hf_small_2503/model(…):  34% 274M/810M [00:04<00:07, 71.6MB/s]
# models/MFR/unimernet_hf_small_2503/model(…):  42% 341M/810M [00:05<00:05, 82.3MB/s]
# models/MFR/unimernet_hf_small_2503/model(…):  50% 408M/810M [00:05<00:04, 97.3MB/s]
# models/MFR/unimernet_hf_small_2503/model(…):  59% 475M/810M [00:06<00:03, 99.4MB/s]
# models/MFR/unimernet_hf_small_2503/model(…):  67% 542M/810M [00:06<00:02, 111MB/s]
# models/MFR/unimernet_hf_small_2503/model(…):  75% 609M/810M [00:07<00:01, 116MB/s]
# models/MFR/unimernet_hf_small_2503/model(…):  83% 676M/810M [00:07<00:01, 123MB/s]
# models/MFR/unimernet_hf_small_2503/model(…):  92% 743M/810M [00:09<00:00, 67.5MB/s]
# models/MFR/unimernet_hf_small_2503/model(…): 100% 810M/810M [00:10<00:00, 77.9MB/s]
# Fetching 7 files: 100% 7/7 [00:11<00:00,  1.60s/it]
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1760453600.630129    2025 cuda_dnn.cc:8579] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1760453600.639658    2025 cuda_blas.cc:1407] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# W0000 00:00:1760453600.663905    2025 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1760453600.663944    2025 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1760453600.663954    2025 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1760453600.663961    2025 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# AttributeError: 'MessageFactory' object has no attribute 'GetPrototype'
# AttributeError: 'MessageFactory' object has no attribute 'GetPrototype'
# AttributeError: 'MessageFactory' object has no attribute 'GetPrototype'
# AttributeError: 'MessageFactory' object has no attribute 'GetPrototype'
# AttributeError: 'MessageFactory' object has no attribute 'GetPrototype'
# Fetching 1 files:   0% 0/1 [00:00<?, ?it/s]
# models/Layout/YOLO/doclayout_yolo_docstr(…):   0% 0.00/39.8M [00:00<?, ?B/s]
# models/Layout/YOLO/doclayout_yolo_docstr(…):   0% 192k/39.8M [00:00<02:36, 253kB/s]
# models/Layout/YOLO/doclayout_yolo_docstr(…): 100% 39.8M/39.8M [00:00<00:00, 40.5MB/s]
# Fetching 1 files: 100% 1/1 [00:01<00:00,  1.52s/it]
# Fetching 1 files:   0% 0/1 [00:00<?, ?it/s]
# models/OCR/paddleocr_torch/ch_PP-OCRv5_d(…):   0% 0.00/14.5M [00:00<?, ?B/s]
# models/OCR/paddleocr_torch/ch_PP-OCRv5_d(…):   0% 54.3k/14.5M [00:00<03:59, 60.3kB/s]
# models/OCR/paddleocr_torch/ch_PP-OCRv5_d(…): 100% 14.5M/14.5M [00:01<00:00, 12.8MB/s]
# Fetching 1 files: 100% 1/1 [00:01<00:00,  1.61s/it]
# Fetching 1 files:   0% 0/1 [00:00<?, ?it/s]
# models/OCR/paddleocr_torch/ch_PP-OCRv4_r(…):   0% 0.00/101M [00:00<?, ?B/s]
# models/OCR/paddleocr_torch/ch_PP-OCRv4_r(…):  34% 34.2M/101M [00:00<00:01, 38.3MB/s]
# models/OCR/paddleocr_torch/ch_PP-OCRv4_r(…): 100% 101M/101M [00:01<00:00, 74.1MB/s]
# Fetching 1 files: 100% 1/1 [00:01<00:00,  1.84s/it]
# Fetching 1 files: 100% 1/1 [00:00<00:00, 6842.26it/s]
# Fetching 1 files: 100% 1/1 [00:00<00:00, 7781.64it/s]
# Fetching 1 files:   0% 0/1 [00:00<?, ?it/s]
# models/TabRec/UnetStructure/unet.onnx:   0% 0.00/8.34M [00:00<?, ?B/s]
# models/TabRec/UnetStructure/unet.onnx: 100% 8.34M/8.34M [00:00<00:00, 14.9MB/s]
# Fetching 1 files: 100% 1/1 [00:01<00:00,  1.04s/it]
# Fetching 1 files:   0% 0/1 [00:00<?, ?it/s]
# models/TabRec/SlanetPlus/slanet-plus.onn(…):   0% 0.00/7.76M [00:00<?, ?B/s]
# models/TabRec/SlanetPlus/slanet-plus.onn(…): 100% 7.76M/7.76M [00:00<00:00, 12.5MB/s]
# Fetching 1 files: 100% 1/1 [00:01<00:00,  1.11s/it]
# Fetching 1 files:   0% 0/1 [00:00<?, ?it/s]
# models/TabCls/paddle_table_cls/PP-LCNet_(…):   0% 0.00/6.78M [00:00<?, ?B/s]
# models/TabCls/paddle_table_cls/PP-LCNet_(…): 100% 6.78M/6.78M [00:00<00:00, 11.9MB/s]
# Fetching 1 files: 100% 1/1 [00:01<00:00,  1.04s/it]
# Fetching 1 files: 100% 1/1 [00:00<00:00, 16256.99it/s]
# Fetching 1 files:   0% 0/1 [00:00<?, ?it/s]
# models/OCR/paddleocr_torch/ch_PP-OCRv5_r(…):   0% 0.00/32.6M [00:00<?, ?B/s]
# models/OCR/paddleocr_torch/ch_PP-OCRv5_r(…): 100% 32.6M/32.6M [00:00<00:00, 37.3MB/s]
# Fetching 1 files: 100% 1/1 [00:01<00:00,  1.36s/it]
# Fetching 1 files:   0% 0/1 [00:00<?, ?it/s]
# models/OriCls/paddle_orientation_classif(…):   0% 0.00/6.79M [00:00<?, ?B/s]
# models/OriCls/paddle_orientation_classif(…): 100% 6.79M/6.79M [00:00<00:00, 12.4MB/s]
# Fetching 1 files: 100% 1/1 [00:01<00:00,  1.03s/it]
# 2025-10-14 14:53:47.695 | INFO     | mineru.backend.pipeline.model_init:__init__:248 - DocAnalysis init done!
# 2025-10-14 14:53:47.695 | INFO     | mineru.backend.pipeline.pipeline_analyze:custom_model_init:65 - model init cost: 56.690688371658325
# Layout Predict: 100% 30/30 [00:06<00:00,  4.67it/s]
# MFD Predict: 100% 30/30 [00:07<00:00,  3.89it/s]
# MFR Predict: 100% 115/115 [00:08<00:00, 14.29it/s]
# Table-ocr det: 100% 26/26 [00:02<00:00, 11.70it/s]
# Fetching 1 files: 100% 1/1 [00:00<00:00, 16070.13it/s]
# Fetching 1 files: 100% 1/1 [00:00<00:00, 8542.37it/s]
# Table-ocr rec ch: 100% 952/952 [00:08<00:00, 115.77it/s]
# Table-wireless Predict: 100% 26/26 [00:05<00:00,  4.80it/s]
# Table-wired Predict:   0% 0/26 [00:00<?, ?it/s]
# Fetching 1 files: 100% 1/1 [00:00<00:00, 15141.89it/s]
# Table-wired Predict: 100% 26/26 [00:28<00:00,  1.10s/it]
# OCR-det Predict:   0% 0/30 [00:00<?, ?it/s]
# Fetching 1 files: 100% 1/1 [00:00<00:00, 16131.94it/s]
#
# Fetching 1 files: 100% 1/1 [00:00<00:00, 8192.00it/s]
# OCR-det Predict: 100% 30/30 [00:11<00:00,  2.50it/s]
# Processing pages:   0% 0/30 [00:00<?, ?it/s]
# Fetching 2 files:   0% 0/2 [00:00<?, ?it/s]
#
# config.json: 24.1kB [00:00, 65.6MB/s]
#
# Fetching 2 files:  50% 1/2 [00:00<00:00,  2.80it/s]
#
# models/ReadingOrder/layout_reader/model.(…):   0% 0.00/713M [00:00<?, ?B/s]
#
# models/ReadingOrder/layout_reader/model.(…):   0% 43.1k/713M [00:02<9:16:15, 21.4kB/s]
#
# models/ReadingOrder/layout_reader/model.(…):   1% 8.54M/713M [00:02<02:29, 4.72MB/s]
#
# models/ReadingOrder/layout_reader/model.(…):  11% 75.6M/713M [00:03<00:18, 34.6MB/s]
#
# models/ReadingOrder/layout_reader/model.(…):  20% 143M/713M [00:03<00:09, 59.6MB/s]
#
# models/ReadingOrder/layout_reader/model.(…):  26% 185M/713M [00:04<00:08, 58.9MB/s]
#
# models/ReadingOrder/layout_reader/model.(…):  35% 252M/713M [00:05<00:07, 63.1MB/s]
#
# models/ReadingOrder/layout_reader/model.(…):  45% 319M/713M [00:06<00:05, 73.9MB/s]
#
# models/ReadingOrder/layout_reader/model.(…):  54% 386M/713M [00:06<00:03, 93.4MB/s]
#
# models/ReadingOrder/layout_reader/model.(…):  64% 453M/713M [00:07<00:02, 94.9MB/s]
#
# models/ReadingOrder/layout_reader/model.(…):  81% 579M/713M [00:08<00:01, 110MB/s]
#
# models/ReadingOrder/layout_reader/model.(…):  91% 646M/713M [00:08<00:00, 121MB/s]
#
# models/ReadingOrder/layout_reader/model.(…): 100% 713M/713M [00:08<00:00, 79.9MB/s]
#
# Fetching 2 files: 100% 2/2 [00:09<00:00,  4.76s/it]
# Processing pages: 100% 30/30 [00:15<00:00,  1.92it/s]
# OCR-rec Predict: 100% 13/13 [00:00<00:00, 133.49it/s]
# 2025-10-14 14:55:26.217 | INFO     | mineru.cli.common:_process_output:155 - local output dir is /content/sample_data/TBS_Handbook-2022/txt

# %%
import shutil
import os

output_dir = '/content/sample_data/TBS_Handbook-2022/txt'
zip_path = '/content/TBS_Handbook-2022_txt.zip'

# Create a zip archive of the output directory
shutil.make_archive(zip_path.replace('.zip', ''), 'zip', output_dir)

# Provide a link to download the zip file
from google.colab import files
files.download(zip_path)
